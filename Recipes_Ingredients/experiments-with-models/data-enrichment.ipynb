# %%
import pandas as pd
import numpy as np

recipes = pd.read_csv('parsed_recipes.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
recipes.head()
# Out:
#        id                                               name  \
# 0   76133                    Reuben and Swiss Casserole Bake
# 1  392934  Safe to Eat Raw Chocolate Chip Oreo Cookie &qu...
# 2  489452                                Teriyaki Pork Chops
# 3  318331                              Granny's Butter Rolls
# 4  384761                          Chocolate Mousse Cupcakes
#
#                                          description  \
# 0  I think this is even better than a reuben sand...
# 1  I was searching the web for something like thi...
# 2  I made these on a whim and they are my husband...
# 3  Recipe from Crystal Van Poppe in her booklet "...
# 4  From The Cupcake Deck by Elinor Klivans.The ad...
#
#                                      ingredients_raw  \
# 0  ['1/2-1   lb    corned beef, cooked and choppe...
# 1  ['1/2  cup    butter, room temperature ', '1/2...
# 2  ['1 (16   ounce) bottle   teriyaki sauce', '4 ...
# 3  ['2 1/4  cups    biscuit mix', '2/3  cup    wa...
# 4  ['3/4  cup    heavy whipping cream', '2   tabl...
#
#                                                steps  servings serving_size  \
# 0  ["Set oven to 350 degrees F.", "Butter a 9 x 1...       4.0    1 (207 g)
# 1  ["Cream butter and sugars together.", "Blend i...      24.0     1 (26 g)
# 2  ["I like to marinade them overnight in a ziplo...       4.0    1 (313 g)
# 3  ["Mix biscuit mix and water until a soft dough...      12.0     1 (91 g)
# 4  ["FOR CHOCOLATE GANACHE FROSTING (Makes about ...      12.0    1 (155 g)
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['15-minutes-or-less', 'time-to-make', 'course...
# 2  ['weeknight', '15-minutes-or-less', 'time-to-m...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['time-to-make', 'course', 'preparation', 'cup...
#
#                                          ingredients  \
# 0  ['corned beef', 'thousand island dressing', 's...
# 1  ['butter', 'brown sugar', 'granulated sugar', ...
# 2                   ['teriyaki sauce', 'pork chops']
# 3  ['biscuit mix', 'water', 'granulated sugar', '...
# 4  ['heavy whipping cream', 'unsalted butter', 's...
#
#                                              amounts  \
# 0  [{'unit': 'pound', 'amount_min': 0.5, 'amount_...
# 1  [{'unit': 'cup', 'amount': 0.5}, {'unit': 'cup...
# 2  [{'unit': 'ounce', 'amount': 16.0}, {'unit': '...
# 3  [{'unit': 'cup', 'amount': 2.25}, {'unit': 'cu...
# 4  [{'unit': 'cup', 'amount': 0.75}, {'unit': 'ta...
#
#                                          amount_gram  serving_size_numeric  \
# 0   ['226.8-453.6', 60.0, 453.6, 226.8, 150.0, 53.9]                 207.0
# 1  [107.8, 100.0, 41.4, 60.0, 3.5, 360.0, 1.6, 21...                  26.0
# 2                                     [453.6, 920.0]                 313.0
# 3             [270.0, 151.3, 82.8, 53.9, 480.0, 4.9]                  91.0
# 4  [180.0, 29.6, 255.1, 2.3, 180.0, 300.0, 29.6, ...                 155.0
#
#    predicted_total  actual_total  approx_rate  total_recipe_weight  \
# 0           1284.5         828.0     0.644609               1284.5
# 1            943.3         624.0     0.661507                943.3
# 2           1373.6        1252.0     0.911474               1373.6
# 3           1042.9        1092.0     1.047080               1042.9
# 4           1918.5        1860.0     0.969507               1918.5
#
#    recipe_energy_per100g  recipe_carbohydrates_per100g  \
# 0             837.891086                      8.031474
# 1            1736.646273                     62.849303
# 2             850.683285                      9.387697
# 3             813.073064                     30.019476
# 4            1587.320070                     41.946135
#
#    recipe_proteins_per100g  recipe_fat_per100g  recipe_energy_kcal_per100g  \
# 0                12.647610           13.490992                  200.260776
# 1                 5.789453           17.069299                  415.068421
# 2                14.166450           10.807455                  203.318185
# 3                 3.678463            6.370956                  194.329126
# 4                 2.892101           22.968018                  379.378602
#
#    recipe_energy_per_serving  recipe_carbohydrates_per_serving  \
# 0                1734.434548                         16.625151
# 1                 451.528031                         16.340819
# 2                2662.638681                         29.383492
# 3                 739.896488                         27.317723
# 4                2460.346109                         65.016509
#
#    recipe_proteins_per_serving  recipe_fat_per_serving  \
# 0                    26.180553               27.926353
# 1                     1.505258                4.438018
# 2                    44.340987               33.827334
# 3                     3.347401                5.797570
# 4                     4.482757               35.600429
#
#    recipe_energy_kcal_per_serving  \
# 0                      414.539806
# 1                      107.917789
# 2                      636.385918
# 3                      176.839505
# 4                      588.036833
#
#                                         steps_parsed  steps_validated
# 0  ['Set oven to 350 degrees F.', 'Butter a 9 x 1...             True
# 1  ['Cream butter and sugars together.', 'Blend i...             True
# 2  ['I like to marinade them overnight in a ziplo...             True
# 3  ['Mix biscuit mix and water until a soft dough...             True
# 4  ['\\"FOR CHOCOLATE GANACHE FROSTING (Makes abo...             True

# %%
# Convert stringified columns into an actual list
import ast

def safe_ast_parse(s):
    try:
        parsed = ast.literal_eval(s)
        return parsed if isinstance(parsed,list) else None
    except Exception as e:
        return None
    
recipes['parsed_steps'] = recipes['steps'].apply(safe_ast_parse)
recipes['validated_steps'] = recipes['parsed_steps'].notna()

print(f"Successfully parsed: {recipes['validated_steps'].sum()}")
print(f"Failed: {len(recipes) - recipes['validated_steps'].sum()}")
# Out:
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# <unknown>:1: SyntaxWarning: invalid decimal literal
# Successfully parsed: 113784
# Failed: 20370
# <unknown>:1: SyntaxWarning: invalid decimal literal

# %%
# Drop rows where steps couldn't be parsed into a list
recipes = recipes[recipes['validated_steps']].copy()

# drop the helper columns
recipes.drop(columns=['parsed_steps', 'validated_steps'], inplace=True)

# Check the new shape
print(f"Remaining rows after dropping invalid ones: {len(recipes)}")
# Out:
# Remaining rows after dropping invalid ones: 113784

# %%
recipes['ingredients'] = recipes['ingredients'].apply(ast.literal_eval)

# %%
recipes['amount_gram'] = recipes['amount_gram'].apply(ast.literal_eval)

# %%
recipes['amounts'] = recipes['amounts'].apply(ast.literal_eval)

# %%
recipes['tags'] = recipes['tags'].apply(ast.literal_eval)

# %%
all_tags = [tag for tags in recipes['tags'] for tag in tags]
unique_tags = set(all_tags)
unique_tags = sorted(unique_tags)
# Display
print(f"Total unique tags: {len(unique_tags)}")
print(unique_tags)
# Out:
# Total unique tags: 533
# ['', '1-day-or-more', '15-minutes-or-less', '3-steps-or-less', '30-minutes-or-less', '4-hours-or-less', '5-ingredients-or-less', '60-minutes-or-less', 'a1-sauce', 'african', 'american', 'amish-mennonite', 'angolan', 'appetizers', 'apples', 'april-fools-day', 'argentine', 'artichoke', 'asian', 'asparagus', 'australian', 'austrian', 'avocado', 'bacon', 'baja', 'baking', 'bananas', 'bar-cookies', 'barbecue', 'bass', 'bath-beauty', 'bean-soup', 'beans', 'beans-soups', 'bear', 'beef', 'beef-liver', 'beef-organ-meats', 'beef-ribs', 'beef-sauces', 'beef-sausage', 'beginner-cook', 'beijing', 'belgian', 'berries', 'beverages', 'birthday', 'biscotti', 'bisques-cream-soups', 'bizarre', 'black-beans', 'blueberries', 'bok-choys', 'brazilian', 'bread-machine', 'bread-pudding', 'breads', 'breakfast', 'breakfast-eggs', 'brewing', 'brisket', 'british-columbian', 'broccoli', 'broil', 'brown-bag', 'brown-rice', 'brownies', 'brunch', 'burgers', 'cabbage', 'cajun', 'cake-fillings-and-frostings', 'cakes', 'californian', 'cambodian', 'camping', 'canadian', 'candy', 'canning', 'cantonese', 'caribbean', 'carrots', 'casseroles', 'casseroles-one-dish-meal', 'catfish', 'cauliflower', 'celebrity', 'central-american', 'chard', 'cheese', 'cheesecake', 'cherries', 'chick-peas-garbanzos', 'chicken', 'chicken-breasts', 'chicken-livers', 'chicken-thighs-legs', 'chilean', 'chili', 'chinese', 'chinese-new-year', 'chocolate', 'chocolate-chip-cookies', 'chowders', 'christmas', 'chutneys', 'cinco-de-mayo', 'citrus', 'clams', 'clear-soups', 'cobblers-and-crisps', 'cocktails', 'coconut', 'cod', 'coffee-cakes', 'collard-greens', 'college', 'colombian', 'comfort-food', 'condiments-etc', 'congolese', 'cookies-and-brownies', 'cookies-and-brownies-nuts', 'cooking-mixes', 'copycat', 'corn', 'costa-rican', 'course', 'crab', 'crawfish', 'creole', 'crock-pot-main-dish', 'crock-pot-slow-cooker', 'crusts-pastry-dough-2', 'cuban', 'cuisine', 'cupcakes', 'curries', 'czech', 'dairy-free', 'danish', 'deep-fry', 'deer', 'dehydrator', 'desserts', 'diabetic', 'dietary', 'dinner-party', 'dips', 'dips-lunch-snacks', 'drop-cookies', 'duck', 'duck-breasts', 'dutch', 'easter', 'easy', 'ecuadorean', 'egg-free', 'eggplant', 'eggs', 'eggs-breakfast', 'eggs-dairy', 'egyptian', 'elbow-macaroni', 'elk', 'english', 'equipment', 'ethiopian', 'european', 'fall', 'fathers-day', 'filipino', 'fillings-and-frostings-chocolate', 'fillings-and-frostings-fruit', 'finger-food', 'finnish', 'fish', 'flat-shapes', 'food-processor-blender', 'for-1-or-2', 'for-large-groups', 'fourth-of-july', 'free-of-something', 'freezer', 'french', 'freshwater-fish', 'from-scratch', 'frozen-desserts', 'fruit', 'fudge', 'garnishes', 'gelatin', 'gelatin-fruit', 'georgian', 'german', 'gifts', 'gluten-free', 'goose', 'grains', 'granola-and-porridge', 'grapes', 'greek', 'green-yellow-beans', 'greens', 'grilling', 'ground-beef', 'guatemalan', 'gumbo', 'halibut', 'halloween', 'halloween-cakes', 'halloween-cocktails', 'halloween-cupcakes', 'ham', 'hand-formed-cookies', 'hanukkah', 'hawaiian', 'healthy', 'healthy-2', 'heirloom-historical', 'heirloom-historical-recipes', 'herb-and-spice-mixes', 'hidden-valley-ranch', 'high-calcium', 'high-fiber', 'high-in-something', 'high-protein', 'holiday-event', 'homeopathy-remedies', 'honduran', 'household-cleansers', 'hunan', 'hungarian', 'ice-cream', 'icelandic', 'independence-day', 'indian', 'indonesian', 'inexpensive', 'infant-baby-friendly', 'iranian-persian', 'iraqi', 'irish', 'irish-st-patricks-day', 'italian', 'jams-and-preserves', 'japanese', 'jellies', 'jewish-ashkenazi', 'jewish-sephardi', 'kid-friendly', 'kiwifruit', 'korean', 'kosher', 'kwanzaa', 'labor-day', 'lactose', 'lamb-sheep', 'laotian', 'lasagna', 'lebanese', 'leftovers', 'lemon', 'lemon-cake', 'lemon-desserts', 'lentils', 'lettuces', 'libyan', 'lime', 'lobster', 'long-grain-rice', 'low-calorie', 'low-carb', 'low-cholesterol', 'low-fat', 'low-in-something', 'low-protein', 'low-saturated-fat', 'low-sodium', 'lunch', 'macaroni-an ...

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113784 entries, 0 to 134153
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   id                                113784 non-null  int64
#  1   name                              113784 non-null  object
#  2   description                       113181 non-null  object
#  3   ingredients_raw                   113784 non-null  object
#  4   steps                             113784 non-null  object
#  5   servings                          113784 non-null  float64
#  6   serving_size                      113784 non-null  object
#  7   tags                              113784 non-null  object
#  8   ingredients                       113784 non-null  object
#  9   amounts                           113784 non-null  object
#  10  amount_gram                       113784 non-null  object
#  11  serving_size_numeric              113784 non-null  float64
#  12  predicted_total                   113784 non-null  float64
#  13  actual_total                      113784 non-null  float64
#  14  approx_rate                       113784 non-null  float64
#  15  total_recipe_weight               113784 non-null  float64
#  16  recipe_energy_per100g             109891 non-null  float64
#  17  recipe_carbohydrates_per100g      108674 non-null  float64
#  18  recipe_proteins_per100g           109381 non-null  float64
#  19  recipe_fat_per100g                108693 non-null  float64
#  20  recipe_energy_kcal_per100g        109891 non-null  float64
#  21  recipe_energy_per_serving         109891 non-null  float64
#  22  recipe_carbohydrates_per_serving  108674 non-null  float64
#  23  recipe_proteins_per_serving       109381 non-null  float64
#  24  recipe_fat_per_serving            108693 non-null  float64
#  25  recipe_energy_kcal_per_serving    109891 non-null  float64
#  26  steps_parsed                      113784 non-null  object
#  27  steps_validated                   113784 non-null  bool
# dtypes: bool(1), float64(16), int64(1), object(10)
# memory usage: 24.4+ MB

# %%
pd.set_option('display.max_colwidth', None)

# %%
recipes.head(1)
# Out:
#       id                             name  \
# 0  76133  Reuben and Swiss Casserole Bake
#
#                                                                                                            description  \
# 0  I think this is even better than a reuben sandwich, I bet you will probably eat the whole casserole by yourself! :)
#
#                                                                                                                                                                                                                                                                                                         ingredients_raw  \
# 0  ['1/2-1   lb    corned beef, cooked and chopped ', '1/4  cup    thousand island dressing (Kraft is best)', '1 (16   ounce) can   sauerkraut, drained and rinsed with cold water ', '1/2  lb    swiss cheese, shredded ', '6   slices    rye bread, crumbled into very small pieces ', '1/4  cup    butter, melted ']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                   steps  \
# 0  ["Set oven to 350 degrees F.", "Butter a 9 x 13-inch casserole dish.", "Place the corned beef in the bottom on the casserole dish then dot all over with the dressing.", "Spread the sauerkraut over the top of the dressing then top with the grated Swiss cheese.", "Toss the breadcrumbs with the butter in a bowl then sprinkle evenly over the the cheese.", "Bake for 25-30 mins, or until bubbly.", "NOTE; if desired the rye bread topping can be doubled."]
#
#    servings serving_size  \
# 0       4.0    1 (207 g)
#
#                                                                                                                                             tags  \
# 0  [60-minutes-or-less, time-to-make, course, main-ingredient, preparation, casseroles, main-dish, eggs-dairy, oven, cheese, dietary, equipment]
#
#                                                                             ingredients  \
# 0  [corned beef, thousand island dressing, sauerkraut, swiss cheese, rye bread, butter]
#
#                                                                                                                                                                                                                                amounts  \
# 0  [{'unit': 'pound', 'amount_min': 0.5, 'amount_max': 1.0}, {'unit': 'cup', 'amount': 0.25}, {'unit': 'ounce', 'amount': 16.0}, {'unit': 'pound', 'amount': 0.5}, {'unit': 'slices', 'amount': 6.0}, {'unit': 'cup', 'amount': 0.25}]
#
#                                       amount_gram  serving_size_numeric  \
# 0  [226.8-453.6, 60.0, 453.6, 226.8, 150.0, 53.9]                 207.0
#
#    predicted_total  actual_total  approx_rate  total_recipe_weight  \
# 0           1284.5         828.0     0.644609               1284.5
#
#    recipe_energy_per100g  recipe_carbohydrates_per100g  \
# 0             837.891086                      8.031474
#
#    recipe_proteins_per100g  recipe_fat_per100g  recipe_energy_kcal_per100g  \
# 0                 12.64761           13.490992                  200.260776
#
#    recipe_energy_per_serving  recipe_carbohydrates_per_serving  \
# 0                1734.434548                         16.625151
#
#    recipe_proteins_per_serving  recipe_fat_per_serving  \
# 0                    26.180553               27.926353
#
#    recipe_energy_kcal_per_serving  \
# 0                      414.539806
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            steps_parsed  \
# 0  ['Set oven to 350 degrees F.', 'Butter a 9 x 13-inch casserole dish.', 'Place the corned beef in the bottom on the casserole dish then dot all over with the dressing.', 'Spread the sauerkraut over the top of the dressing then top with the grated Swiss cheese.', 'Toss the breadcrumbs with the butter in a bowl then sprinkle evenly over the the cheese.', 'Bake for 25-30 mins, or until bubbly.', 'NOTE; if desired the rye bread topping can be doubled.']
#
#    steps_validated
# 0             True

# %%
recipes.to_csv("recipes_revisited.csv",index=False)

# %%
import pandas as pd
import numpy as np
recipes = pd.read_csv("recipes_revisited.csv")

# %%
import ast
recipes['ingredients'] = recipes['ingredients'].apply(ast.literal_eval)

# %%
# First, let's extract all unique ingredients from the dataframe
all_ingredients = []

# Collect all ingredients from all recipes
for ingredient_list in recipes['ingredients']:
    if isinstance(ingredient_list, list):
        all_ingredients.extend(ingredient_list)

# Count frequency of each ingredient
from collections import Counter
ingredient_counts = Counter(all_ingredients)

print(f"Total ingredient occurrences: {len(all_ingredients)}")
print(f"Unique ingredients: {len(ingredient_counts)}")

# Convert to dataframe for easier analysis

ingredients_df = pd.DataFrame(
    ingredient_counts.items(), 
    columns=['ingredient', 'frequency']
).sort_values('frequency', ascending=False)
# Out:
# Total ingredient occurrences: 968758
# Unique ingredients: 24533

# %%
print("\nTop 20 most common ingredients:")
print(ingredients_df.head(20))

# Look at bottom 20 (potential misspellings)
print("\nLeast common ingredients (potential misspellings):")
print(ingredients_df.tail(20))
# Out:
# Top 20 most common ingredients:
#             ingredient  frequency
# 11                salt      48042
# 43               sugar      30782
# 5               butter      28939
# 44                eggs      21790
# 62              garlic      19350
# 17               water      18116
# 29               onion      17199
# 10               flour      14872
# 8                 milk      14435
# 57              pepper      13454
# 6          brown sugar      12147
# 51           olive oil      11989
# 27   all-purpose flour      11938
# 40       baking powder      11856
# 41         baking soda      10203
# 121                egg      10103
# 18             vanilla       9726
# 131           cinnamon       7920
# 9      vanilla extract       7441
# 34         lemon juice       7255
#
# Least common ingredients (potential misspellings):
#                                    ingredient  frequency
# 13456        no-sugar-added crushed pineapple          1
# 13458              frozen whole-grain waffles          1
# 13460                        boston pork butt          1
# 13461  pilsbury moist supreme yellow cake mix          1
# 13462              raw unsalted pumpkin seeds          1
# 13463                       fireweed blossoms          1
# 13464                   white clover blossoms          1
# 13465             aidelles andouille sausages          1
# 13466                               deli buns          1
# 13467                  accent sason seasoning          1
# 13468                              rock sugar          1
# 13469              whole grain granola cereal          1
# 13470              dried mixed tropical fruit          1
# 13472                         boneless salmon          1
# 13473                     smoked fish fillets          1
# 13474        certified angus beef ground beef          1
# 13476              buddig smoked chipped beef          1
# 13477                     oysters with liquor          1
# 13478      southern comfort (whiskey liqueur)          1
# 24532              stovetop pork stuffing mix          1

# %%
from fuzzywuzzy import fuzz
from collections import defaultdict
import time
import json

def cluster_ingredients_optimized(ingredients_df, similarity_threshold=85):
    """
    Cluster ingredients with optimizations for speed
    """
    print(f"Starting clustering of {len(ingredients_df)} ingredients...")
    start_time = time.time()
    
    # Sort by frequency - process common ingredients first
    ingredients_df = ingredients_df.sort_values('frequency', ascending=False)
    all_ingredients = ingredients_df.to_dict('records')
    
    clusters = []
    processed = set()
    
    for i, ing1 in enumerate(all_ingredients):
        if i % 1000 == 0:
            elapsed = time.time() - start_time
            print(f"Processed {i}/{len(all_ingredients)} ingredients ({elapsed/60:.1f} minutes)")
        
        if ing1['ingredient'] in processed:
            continue
        
        # Start new cluster
        cluster = {
            'canonical': ing1['ingredient'],
            'variants': [ing1['ingredient']],
            'frequencies': {ing1['ingredient']: ing1['frequency']}
        }
        processed.add(ing1['ingredient'])
        
        # Only check ingredients that haven't been processed
        for j in range(i + 1, len(all_ingredients)):
            ing2 = all_ingredients[j]
            
            if ing2['ingredient'] in processed:
                continue
            
            # Quick length check - very different lengths unlikely to match
            len_ratio = len(ing1['ingredient']) / len(ing2['ingredient'])
            if len_ratio < 0.5 or len_ratio > 2.0:
                continue
            
            # Calculate similarity
            ratio = fuzz.ratio(ing1['ingredient'].lower(), ing2['ingredient'].lower())
            
            # If close enough, do more expensive checks
            if ratio > 70:
                partial = fuzz.partial_ratio(ing1['ingredient'].lower(), ing2['ingredient'].lower())
                
                # Check containment for ingredients > 4 chars
                contains = False
                if len(ing1['ingredient']) > 4 and len(ing2['ingredient']) > 4:
                    contains = (ing1['ingredient'].lower() in ing2['ingredient'].lower() or 
                              ing2['ingredient'].lower() in ing1['ingredient'].lower())
                
                if ratio > similarity_threshold or partial > 90 or contains:
                    cluster['variants'].append(ing2['ingredient'])
                    cluster['frequencies'][ing2['ingredient']] = ing2['frequency']
                    processed.add(ing2['ingredient'])
        
        # Only keep clusters with multiple items
        if len(cluster['variants']) > 1:
            # Calculate total frequency
            cluster['total_frequency'] = sum(cluster['frequencies'].values())
            clusters.append(cluster)
    
    total_time = time.time() - start_time
    print(f"\nClustering completed in {total_time/60:.1f} minutes")
    
    return clusters

# Run on your data
print("Running ingredient clustering...")
clusters = cluster_ingredients_optimized(ingredients_df)

# Sort by impact (total frequency)
clusters.sort(key=lambda x: x['total_frequency'], reverse=True)

# Save results
with open('ingredient_clusters.json', 'w', encoding='utf-8') as f:
    json.dump(clusters, f, indent=2, ensure_ascii=False)

# Show top clusters
print(f"\nFound {len(clusters)} ingredient clusters")
print("\nTop 20 clusters by total frequency:")
for i, cluster in enumerate(clusters[:20]):
    print(f"\n{i+1}. {cluster['canonical']} (total frequency: {cluster['total_frequency']})")
    print(f"   Variants: {', '.join(cluster['variants'])}")

# Create mapping dictionary for easy lookup
ingredient_mapping = {}
for cluster in clusters:
    for variant in cluster['variants']:
        ingredient_mapping[variant] = cluster['variants']

# Save mapping
with open('ingredient_mapping.json', 'w', encoding='utf-8') as f:
    json.dump(ingredient_mapping, f, indent=2, ensure_ascii=False)

print("\nSaved to:")
print("- ingredient_clusters.json (full cluster data)")
print("- ingredient_mapping.json (variant lookup)")
# Out:
# Running ingredient clustering...
# Starting clustering of 24533 ingredients...
# Processed 0/24533 ingredients (0.0 minutes)
# Processed 1000/24533 ingredients (0.5 minutes)
# Processed 2000/24533 ingredients (0.9 minutes)
# Processed 3000/24533 ingredients (1.2 minutes)
# Processed 4000/24533 ingredients (1.5 minutes)
# Processed 5000/24533 ingredients (1.7 minutes)
# Processed 6000/24533 ingredients (1.9 minutes)
# Processed 7000/24533 ingredients (2.1 minutes)
# Processed 8000/24533 ingredients (2.3 minutes)
# Processed 9000/24533 ingredients (2.5 minutes)
# Processed 10000/24533 ingredients (2.6 minutes)
# Processed 11000/24533 ingredients (2.8 minutes)
# Processed 12000/24533 ingredients (2.9 minutes)
# Processed 13000/24533 ingredients (3.0 minutes)
# Processed 14000/24533 ingredients (3.1 minutes)
# Processed 15000/24533 ingredients (3.3 minutes)
# Processed 16000/24533 ingredients (3.3 minutes)
# Processed 17000/24533 ingredients (3.4 minutes)
# Processed 18000/24533 ingredients (3.5 minutes)
# Processed 19000/24533 ingredients (3.5 minutes)
# Processed 20000/24533 ingredients (3.6 minutes)
# Processed 21000/24533 ingredients (3.6 minutes)
# Processed 22000/24533 ingredients (3.6 minutes)
# Processed 23000/24533 ingredients (3.7 minutes)
# Processed 24000/24533 ingredients (3.7 minutes)
#
# Clustering completed in 3.7 minutes
#
# Found 3996 ingredient clusters
#
# Top 20 clusters by total frequency:
#
# 1. salt (total frequency: 48057)
#    Variants: salt, saltine, nu-salt, salt,', nu salt, salt,., salt, &
#
# 2. butter (total frequency: 32014)
#    Variants: butter, buttermilk, cold butter, soft butter, real butter, firm butter, nut butter, butter buds, herb butter, shea butter, cub butter, buttery oil, aloe butter, ghee butter, hard butter, hot butter, pure butter
#
# 3. eggs (total frequency: 31893)
#    Variants: eggs, egg
#
# 4. sugar (total frequency: 30890)
#    Variants: sugar, raw sugar, red sugar, sugar*
#
# 5. onion (total frequency: 23310)
#    Variants: onion, onions, red onion, dry onion, raw onion, onion,., onion, --
#
# 6. garlic (total frequency: 20756)
#    Variants: garlic, garlic salt, garlic oil, freh garlic
#
# 7. water (total frequency: 19299)
#    Variants: water, hot water, ice water, tap water, lye water, water &
#
# 8. pepper (total frequency: 15903)
#    Variants: pepper, red pepper, bell pepper, pepperoni, red peppers, peppercorns, peppercorn, hot pepper, hot peppers, add pepper, peppermint, pink pepper
#
# 9. flour (total frequency: 15423)
#    Variants: flour, cornflour, rye flour, soy flour, oat flour, ap flour, gf flour
#
# 10. brown sugar (total frequency: 15213)
#    Variants: brown sugar, light brown sugar, dark brown sugar, golden brown sugar, soft brown sugar, light-brown sugar, brown sugar twin, splenda brown sugar, raw brown sugar, truvia brown sugar, vegan brown sugar, lightly brown sugar, chinese brown sugar, loose brown sugar, brown sugar cube, extra brown sugar, light brow sugar, good brown sugar, lite brown sugar
#
# 11. milk (total frequency: 14698)
#    Variants: milk, soymilk, 2% milk
#
# 12. all-purpose flour (total frequency: 12412)
#    Variants: all-purpose flour, unbleached all-purpose flour, all purpose flour, gold medal all-purpose flour, plain all-purpose flour, bleached all purpose flour, gluten free all-purpose flour, white lily all-purpose flour, whole wheat all-purpose flour, all-puporse flour, unsiftede all-purpose flour, all purpous flour, all-purpose flour (*), gold medal® all-purpose flour, sll all-purpose flour, gluten-free all-purpose flour, all-puroose flour, maida flour (all-purpose flour), unbleached all purpose flour, all-purposed flour, el peto all-purpose flour, robin hood all-purpose flour, tablesppons all-purpose flour, all-porpose flour
#
# 13. olive oil (total frequency: 12216)
#    Variants: olive oil, olive, light olive oil, virgin olive oil, lite olive oil, mild olive oil, fruity olive oil, pure olive oil, extra olive oil, tbspolive oil, pepper olive oil, oilve oil, olve oil, veg oil, goya olive oil, basil olive oil, blsp olive oil, bsp olive oil, good olive oil
#
# 14. baking powder (total frequency: 11864)
#    Variants: baking powder, baking powder (heaping), baking powder (b), flat baking powder, passover baking powder, rumsford baking powder
#
# 15. baking soda (total frequency: 10205)
#    Variants: baking soda, baking soda (*), baking soda (level)
#
# 16. vanilla (total frequency: 10007)
#    Variants: vanilla, vanilla bean, real vanilla, vanilla chip, vanilla pod, vanilla rum, raw vanilla, vanilla milk, vanilla coke, gf vanilla
#
# 17. lemon juice (total frequency: 9224)
#    Variants: lemon juice, fresh lemon juice, bottled lemon juice, realemon juice, squeeze lemon juice, meyer lemon juice, lemons juice, raw lemon juice, sweet lemon juice, frozen lemon juice, fish lemon juice
#
# 18. vanilla extract (total frequency: 8505)
#    Variants: vanilla extract, pure vanilla extract, real vanilla extract, clear vanilla extract, raw vanilla extract, natural vanilla extract, mexican vanilla extract, gluten-free vanilla extract, sugar-free vanilla extract, good vanilla extract, vanilla bean extract, vanilla nut extract, madagascar vanilla extract, unsweetened vanilla extract, liquid vanilla extract, vanilla extract (pure), tahitian vanilla extract, vanilla rum extract, vanilla extract (essence), pure vanillia extract, organic vanilla extract, pure vanillla extract, oure vanilla extract, vanillla extract, watkins vanilla extract
#
# 19. cinnamon (total frequency: 8318)
#    Variants: cinnamon, cinnamon stick, cinnamon sugar, cinnamon syrup, cinnamon rolls, cinnamon oil, extra cinnamon, cinnamon bark, cinnamon, &, pure cinnamon
#
# 20. tomatoes (total frequency: 7346)
#    Variants: tomatoes, diced tomatoes, plum tomatoes, roma tomatoes, tomato, ripe tomatoes, whole tomatoes, grape tomatoes, rotel tomatoes, fresh tomatoes, green tomatoes, firm tomatoes, egg tomatoes, dried tomatoes, beef tomatoes, cut tomatoes, baby tomatoes, red tomatoes, meaty tomatoes, sweet tomatoes, bush tomatoes, cubed tomatoes, rice tomatoes, paste tomatoes, chpd tomatoes, chili tomatoes, thin tomatoes, vine tomatoes, tomatoes, --, truss tomatoes, mixed tomatoes, pomi tomatoes
#
# Saved to:
# - ingredient_clusters.json (full cluster data)
# - ingredient_mapping.json (variant lookup)
